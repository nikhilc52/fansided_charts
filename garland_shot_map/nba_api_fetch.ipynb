# %%
from nba_api.stats.endpoints import playercareerstats
import pandas as pd

career = playercareerstats.PlayerCareerStats(player_id='203999')

career.season_totals_regular_season.get_data_frame()
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203999   2015-16        00  1610612743               DEN        21.0
# 1     203999   2016-17        00  1610612743               DEN        22.0
# 2     203999   2017-18        00  1610612743               DEN        23.0
# 3     203999   2018-19        00  1610612743               DEN        24.0
# 4     203999   2019-20        00  1610612743               DEN        25.0
# 5     203999   2020-21        00  1610612743               DEN        26.0
# 6     203999   2021-22        00  1610612743               DEN        27.0
# 7     203999   2022-23        00  1610612743               DEN        28.0
# 8     203999   2023-24        00  1610612743               DEN        29.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0  80  55  1733.0  307  ...   0.811   181   379   560  189   79   50  104
# 1  73  59  2038.0  494  ...   0.825   212   506   718  359   61   55  171
# 2  75  73  2443.0  504  ...   0.850   195   608   803  458   90   61  210
# 3  80  80  2504.0  616  ...   0.821   228   637   865  580  108   55  248
# 4  73  73  2335.0  565  ...   0.817   166   545   711  512   85   44  226
# 5  72  72  2488.0  732  ...   0.868   205   575   780  599   95   48  222
# 6  74  74  2476.0  764  ...   0.810   206   813  1019  584  109   63  281
# 7  69  69  2323.0  646  ...   0.822   167   650   817  678   87   47  247
# 8  79  79  2737.0  822  ...   0.817   223   753   976  708  108   68  237
#
#     PF   PTS
# 0  208   796
# 1  214  1221
# 2  212  1385
# 3  228  1604
# 4  222  1456
# 5  192  1898
# 6  191  2004
# 7  174  1690
# 8  194  2085
#
# [9 rows x 27 columns]

# %%
from nba_api.stats.endpoints import shotchartdetail

response = shotchartdetail.ShotChartDetail(
    team_id=1610612739,
    player_id=1629636,
    season_nullable='2023-24',
    context_measure_simple = 'FGA',
    season_type_all_star='Playoffs'
)
response.get_data_frames()[0]
#response.get_data_frames()[0].to_csv('team_test.csv')
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID     PLAYER_NAME  \
# 0    Shot Chart Detail  0042300131             43    1629636  Darius Garland
# 1    Shot Chart Detail  0042300131             82    1629636  Darius Garland
# 2    Shot Chart Detail  0042300131             86    1629636  Darius Garland
# 3    Shot Chart Detail  0042300131            170    1629636  Darius Garland
# 4    Shot Chart Detail  0042300131            200    1629636  Darius Garland
# ..                 ...         ...            ...        ...             ...
# 166  Shot Chart Detail  0042300205            408    1629636  Darius Garland
# 167  Shot Chart Detail  0042300205            469    1629636  Darius Garland
# 168  Shot Chart Detail  0042300205            486    1629636  Darius Garland
# 169  Shot Chart Detail  0042300205            496    1629636  Darius Garland
# 170  Shot Chart Detail  0042300205            502    1629636  Darius Garland
#
#         TEAM_ID            TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0    1610612739  Cleveland Cavaliers       1                  8
# 1    1610612739  Cleveland Cavaliers       1                  5
# 2    1610612739  Cleveland Cavaliers       1                  5
# 3    1610612739  Cleveland Cavaliers       2                 11
# 4    1610612739  Cleveland Cavaliers       2                  9
# ..          ...                  ...     ...                ...
# 166  1610612739  Cleveland Cavaliers       3                  3
# 167  1610612739  Cleveland Cavaliers       4                  9
# 168  1610612739  Cleveland Cavaliers       4                  8
# 169  1610612739  Cleveland Cavaliers       4                  7
# 170  1610612739  Cleveland Cavaliers       4                  6
#
#      SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                   34  ...  Right Side Center(RC)        16-24 ft.
# 1                   52  ...              Center(C)          24+ ft.
# 2                   23  ...          Right Side(R)         8-16 ft.
# 3                   17  ...   Left Side Center(LC)          24+ ft.
# 4                   20  ...  Right Side Center(RC)        16-24 ft.
# ..                 ...  ...                    ...              ...
# 166                 55  ...   Left Side Center(LC)          24+ ft.
# 167                 59  ...              Center(C)  Less Than 8 ft.
# 168                 19  ...              Center(C)  Less Than 8 ft.
# 169                  0  ...           Left Side(L)        16-24 ft.
# 170                 20  ...          Right Side(R)        16-24 ft.
#
#     SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0              17    87   154                   1               1   20240420
# 1              29    50   286                   1               0   20240420
# 2              11    76    81                   1               1   20240420
# 3              30  -190   243                   1               0   20240420
# 4              16    98   137                   1               0   20240420
# ..            ...   ...   ...                 ...             ...        ...
# 166            29   -99   275                   1               0   20240515
# 167             5   -49    34                   1               0   20240515
# 168             0     2     5                   1               1   20240515
# 169            16  -138    91                   1               0   20240515
# 170            19   192    48                   1               0   20240515
#
#      HTM  VTM
# 0    CLE  ORL
# 1    CLE  ORL
# 2    CLE  ORL
# 3    CLE  ORL
# 4    CLE  ORL
# ..   ...  ...
# 166  BOS  CLE
# 167  BOS  CLE
# 168  BOS  CLE
# 169  BOS  CLE
# 170  BOS  CLE
#
# [171 rows x 24 columns]

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# c:\Users\nikhi\OneDrive\Documents\GitHub\fansided_charts\garland_shot_map
